# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.2415732 , 0.19852112, 0.39820907, 0.47097701, 0.8297994 ,
#        0.79573872, 0.05711788, 0.52383821, 0.97746903, 0.73444934,
#        0.53381729, 0.47189901, 0.26550269, 0.78807218, 0.3147679 ,
#        0.85305924, 0.60307127, 0.40826329, 0.02458458, 0.05823872,
#        0.70995587, 0.13433985, 0.92173094, 0.94815648, 0.22689573,
#        0.11538887, 0.33413619, 0.77658484, 0.18029921, 0.51241079,
#        0.67583248, 0.58131836, 0.79909377, 0.70934352, 0.62651831,
#        0.4286579 , 0.89552394, 0.09214316, 0.80167774, 0.96184776,
#        0.26775295, 0.70623396, 0.07105106, 0.89381214, 0.46323507,
#        0.3546624 , 0.76258399, 0.57999932, 0.46416628, 0.21303726])

# %%
y
# Out:
# array([0.37433188, 0.81598538, 0.55966333, 0.23334381, 0.58949493,
#        0.55840082, 0.90768027, 0.62651776, 0.97811885, 0.80316339,
#        0.36174595, 0.4710379 , 0.08669976, 0.40488431, 0.53775749,
#        0.75889118, 0.22331205, 0.66567819, 0.5874755 , 0.33206254,
#        0.23824526, 0.66680721, 0.75417181, 0.73470268, 0.22398382,
#        0.77676048, 0.105283  , 0.91627679, 0.24802343, 0.46496706,
#        0.35762033, 0.6442461 , 0.80374453, 0.18722642, 0.22040064,
#        0.02528457, 0.54242436, 0.53497713, 0.24080874, 0.25812793,
#        0.67555735, 0.9494431 , 0.56861683, 0.9178386 , 0.65521731,
#        0.6168586 , 0.98003316, 0.57919808, 0.13567692, 0.71045175])

# %% [markdown]
# # Scatter

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(10,5))
plt.scatter(x,y, c='#1EBC6F', alpha=.5, marker='*')  # c = color , alpha = color shade -- lowest value for light color, marker = marker
plt.xlabel("This x axis")
plt.ylabel("This y axis")
plt.title("This is my graph")
plt.grid()

# %%
x = np.linspace(1,10,100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.scatter(x,y)

# %% [markdown]
# # plot

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y, "--r")
plt.xlabel("This x axis")
plt.ylabel("This y axis")
plt.title("This is my graph")
plt.grid()

# %%
x = ['a','b','c','d','e','f']
y= np.random.rand(6)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
y
# Out:
# array([0.34888103, 0.82187145, 0.20434049, 0.22939236, 0.77366046,
#        0.34680847])

# %% [markdown]
# # Bar plot

# %%
plt.bar(x,y, color='r')
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("This is my bar plot")
plt.grid()

# %%
plt.barh(x,y, color='r')  # barh = horisontal
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("This is my bar plot")
plt.grid()

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)

# %% [markdown]
# # histogram
#  it is used when some values are repited

# %%
data = [3,3,3,4,4,4,4,4,5,6,7,7,7,7,8,8,8,8,8]

# %%
plt.hist(data, color= "b")
plt.xlabel("Representing unique val")
plt.ylabel("Representing fig")
plt.title("this is histogram")
plt.savefig("test.png")

# %% [markdown]
# # 3D graph

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z,color='b',alpha=0.8)
plt.xlabel("This x axis")
plt.ylabel("This y axis")

plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(x,y,z)
plt.show()

# %%
fig  = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.bar(x,y,z)
plt.show()
