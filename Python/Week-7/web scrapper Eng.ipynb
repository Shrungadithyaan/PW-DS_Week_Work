# %%
import requests
from bs4 import BeautifulSoup as bs # It helps to convert code into human readable format
from urllib.request import urlopen 
import logging

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
flipakart_url = "https://www.flipkart.com/search?q="+"iphone+14"

# %%
flipakart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone+14'

# %%
urlclient = urlopen(flipakart_url)

# %%
flipakart_page = urlclient.read()

# %%
flipakart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipakart_html = bs(flipakart_page, 'html.parser')

# %%
"https://www.flipkart.com"+"/apple-iphone-14-plus-starlight-128-gb/p/itmc922ddc8af349?pid=MOBGHWFHVCB2YZYR&lid=LSTMOBGHWFHVCB2YZYR7XYF6W&marketplace=FLIPKART&q=iphone+14+plus&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_OrganicAutoSuggest_4_4_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_4_4_na_na_ps&fm=search-autosuggest&iid=e7d070b9-a71a-4980-8159-761e4cc6508e.MOBGHWFHVCB2YZYR.SEARCH&ppt=sp&ppn=sp&ssid=1n7wjlebb40000001687311520858&qH=70897fd4f67467a5"
# Out:
# 'https://www.flipkart.com/apple-iphone-14-plus-starlight-128-gb/p/itmc922ddc8af349?pid=MOBGHWFHVCB2YZYR&lid=LSTMOBGHWFHVCB2YZYR7XYF6W&marketplace=FLIPKART&q=iphone+14+plus&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_OrganicAutoSuggest_4_4_na_na_ps&otracker1=AS_Query_OrganicAutoSuggest_4_4_na_na_ps&fm=search-autosuggest&iid=e7d070b9-a71a-4980-8159-761e4cc6508e.MOBGHWFHVCB2YZYR.SEARCH&ppt=sp&ppn=sp&ssid=1n7wjlebb40000001687311520858&qH=70897fd4f67467a5'

# %%
bigbox = flipakart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone+14&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=ty
# ...

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3] # to remove header part in the divbox

# %%
productlink = "https://www.flipkart.com" + bigbox[0].div.div.div.a['href']

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a["href"])
# Out:
# https://www.flipkart.com/apple-iphone-14-purple-128-gb/p/itm0b581eba85e08?pid=MOBGHWFHQFSQYBFU&lid=LSTMOBGHWFHQFSQYBFU9AP8AR&marketplace=FLIPKART&q=iphone+14&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=3c39b851-1d2a-4a1f-8cfa-4d82cfe6d1ac.MOBGHWFHQFSQYBFU.SEARCH&ppt=None&ppn=None&ssid=o9juslk34w0000001687613389261&qH=860f3715b8db08cd
# https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCX8AI8PX&marketplace=FLIPKART&q=iphone+14&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=3c39b851-1d2a-4a1f-8cfa-4d82cfe6d1ac.MOBGHWFHECFVMDCX.SEARCH&ppt=None&ppn=None&ssid=o9juslk34w0000001687613389261&qH=860f3715b8db08cd
# ...

# %%
product_req= requests.get(productlink)

# %%
product_html = bs(product_req.text,'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.find_all("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">SUNNY KUMAR</p>]

# %%
comment_box[1].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Ganpati Rai'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# SUNNY KUMAR
# Ganpati Rai
# Yogesh Patel
# Waqar ahmed
# Flipkart Customer
# Mohit Kumar
# Deepak kaushik
# Vijay Anandhan
# Abishek Bhattacherjee
# Flipkart Customer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Data_Science\PW\PW-DS_week_work\Python\Week-7\web scrapper Eng.ipynb Cell 24 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:

    print(i.div.div.div.div.text)
# Out:
# 5
# 4
# 1
# 5
# 5
# 5
# 5
# 5
# 5
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Data_Science\PW\PW-DS_week_work\Python\Week-7\web scrapper Eng.ipynb Cell 26 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a>     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p
# Out:
# <p class="_2-N8zT">Just wow!</p>

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Just wow!'

# %%
for i in comment_box:

    print(i.div.div.div.p.text)
# Out:
# Just wow!
# Waste of money!
# Horrible
# Best in the market!
# Simply awesome
# Great product
# Terrific
# Simply awesome
# Just wow!
# Don't waste your money
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Data_Science\PW\PW-DS_week_work\Python\Week-7\web scrapper Eng.ipynb Cell 29 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> for i in comment_box:
# ----> <a href='vscode-notebook-cell:/e%3A/Data_Science/PW/PW-DS_week_work/Python/Week-7/web%20scrapper%20Eng.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a>     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# 'I used iPhone 12 mini and now upgraded with iPhone 14. Camera quality is awesome.Full day battery backup.Super Retina display with high dynamic range is awesome.In terms of camera and battery life is big upgrade for me.READ MORE'

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# I used iPhone 12 mini and now upgraded with iPhone 14. Camera quality is awesome.Full day battery backup.Super Retina display with high dynamic range is awesome.In terms of camera and battery life is big upgrade for me.READ MORE
# Facing heating issues while playing video and using cameraREAD MORE
# Really disappointed with display and performance. Lagging in bgmi with graphics settings smooth + extreme. Hardly 50 fps. While lagging gives 25-30 fps which is frustrating for device like this.READ MORE
# Amazing picture quality, awesome design, mind blowing display and fabulous performance and specially very handy phoneREAD MORE
# Very nice phone. Totally worth itREAD MORE
# ✓Comfortable, high-end build✓OLED screen looks fantastic✓A15 chip performs great✓Good camera upgrades✓Dependable battery lifeREAD MORE
# !!!Enjoy with iphone 14 👍😎✌️ with great camera resolutionREAD MORE
# ...
